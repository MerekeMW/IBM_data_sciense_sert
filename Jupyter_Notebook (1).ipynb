# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mereke Kydyraliyev**

# %% [markdown]
# My desired profession is data scientist

# %% [markdown]
# _I want to become a Data Scientist because a Data Scientist solves important problems and I want to see the results of my work._

# %% [markdown]
# ### The code below print the phrase: "Have a nice day and success in your business!"

# %%
print("Have a nice day and good luck in your business!")
# Out:
# Have a nice day and good luck in your business!

# %% [markdown]
# Image
#
#
# ![%D0%A2%D0%B5%D0%B3%20VBA.jpg](attachment:%D0%A2%D0%B5%D0%B3%20VBA.jpg)
#
# [Google hyperlink](https://www.google.com/)
#
#
# Table
#
# |Col1|Col2|Col3|
# |---|--|--|
# |val1|Val2|Val3|
